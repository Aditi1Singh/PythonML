# %%
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
import string

# %%
data = pd.read_csv('sentiment.csv')
# Keeping only the neccessary columns
data = data[['text','sentiment']]
data.head()
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
data.count()
# Out:
# text         13871
# sentiment    13871
# dtype: int64

# %%
def wordcloud_draw(text):
    #words = ' '.join(data)
    cleaned_word = " ".join([word for word in text.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    return cleaned_word

data['cleaned_text'] = data['text'].apply(lambda x: wordcloud_draw(x))

data.head()
# Out:
#                                                 text sentiment  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
#
#                                         cleaned_text
# 0  How did everyone feel about the Climate Change...
# 1  Didn't catch the full last night. Here are som...
# 2  No mention of Tamir Rice and the was held in C...
# 3  That Carly Fiorina is trending -- hours after ...
# 4  w/ delivered the highest ratings in the histor...

# %%
#Declaring a sample Dataset for trial
sample = [" ","The food was excellent","The food was EXCELLENT","The food was good but the service was pathetic","10/10 for the ambience","Inspite of the food being good, the manager was very rude to us","The food was pathetic","The food was pathetic!!","I would not eat this food for free also",":-)",":-("]

sample_pd = pd.DataFrame({'text':sample})

from nltk.sentiment.vader import SentimentIntensityAnalyzer

posList = []
negList = []
neuList = []

i = 0

data['prediction'] = ''
data['compound'] = ''

threshold = 0

sid = SentimentIntensityAnalyzer()
for sentence in data['cleaned_text']:
    vs = sid.polarity_scores(sentence)
    comp = vs['compound']
    if vs['compound'] > 0.6:
        data['prediction'][i] = 'Positive'
        data['compound'][i] = comp
    elif vs['compound'] < 0:
        data['prediction'][i] = 'Negative'
        data['compound'][i] = comp
    else:
        data['prediction'][i] = 'Neutral'
        data['compound'][i] = comp
    i = i + 1
# Out:
# C:\Users\ADMIN\Anaconda2\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
data.head(20)
# Out:
#                                                  text sentiment  \
# 0   RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1   RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2   RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3   RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4   RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# 5   RT @GregAbbott_TX: @TedCruz: "On my first day ...  Positive
# 6   RT @warriorwoman91: I liked her and was happy ...  Negative
# 7   Going on #MSNBC Live with @ThomasARoberts arou...   Neutral
# 8   Deer in the headlights RT @lizzwinstead: Ben C...  Negative
# 9   RT @NancyOsborne180: Last night's debate prove...  Negative
# 10  @JGreenDC @realDonaldTrump In all fairness #Bi...  Negative
# 11  RT @WayneDupreeShow: Just woke up to tweet thi...  Positive
# 12  Me reading my family's comments about how grea...  Negative
# 13  RT @ArcticFox2016: RT @AllenWestRepub "Dear @J...   Neutral
# 14  RT @pattonoswalt: I loved Scott Walker as Mark...  Positive
# 15  Hey @ChrisChristie exploiting the tragedy of 9...  Negative
# 16  RT @CarolCNN: #DonaldTrump under fire for comm...  Negative
# 17  RT @johncardillo: Guess who had most speaking ...  Negative
# 18  reason comment is funny 'in case you're ignora...  Negative
# 19  RT @PamelaGeller: Huckabee: Paying for transge...  Negative
#
#                                          cleaned_text prediction compound
# 0   How did everyone feel about the Climate Change...    Neutral        0
# 1   Didn't catch the full last night. Here are som...   Positive   0.6369
# 2   No mention of Tamir Rice and the was held in C...    Neutral   0.3818
# 3   That Carly Fiorina is trending -- hours after ...    Neutral        0
# 4   w/ delivered the highest ratings in the histor...    Neutral        0
# 5   "On my first day I will rescind every illegal ...   Negative  -0.5574
# 6   I liked her and was happy when I heard she was...   Positive   0.7579
# 7                  Going on Live with around 2 PM ET.    Neutral        0
# 8   Deer in the headlights Ben Carson, may be the ...    Neutral        0
# 9                      Last night's debate proved it!    Neutral        0
# 10        In all fairness owns that phrase.#GOPDebate    Neutral        0
# 11  Just woke up to tweet this out Best line of th...   Positive   0.6369
# 12  Me reading my family's comments about how grea...   Positive   0.6249
# 13                                              "Dear    Neutral   0.3818
# 14  I loved Scott Walker as Mark Harmon's romantic...   Positive    0.765
# 15  Hey exploiting the tragedy of 9/11 for your ow...   Negative  -0.5994
# 16    under fire for comments about women weigh in on   Negative    -0.34
# 17  Guess who had most speaking time at the modera...    Neutral        0
# 18  reason comment is funny 'in case you're ignora...    Neutral   0.2023
# 19  Huckabee: Paying for transgender surgery for s...    Neutral   0.4215

# %%
temp = data[['sentiment','compound']]
temp['compound'] = temp['compound'].astype(float)
posMax = temp.groupby(['sentiment']).max()
posMin = temp.groupby(['sentiment']).min()
print("Maximum Values:")
print
print(posMax)
print
print("Minimum Values:")
print
print(posMin)
# Out:
# C:\Users\ADMIN\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Maximum Values:
#
#            compound
# sentiment
# Negative     0.9377
# Neutral      0.9153
# Positive     0.9629
#
# Minimum Values:
#
#            compound
# sentiment
# Negative    -0.9812
# Neutral     -0.9239
# Positive    -0.8876

# %%
newdata = data[data['prediction']!='Null']
len(newdata)
# Out:
# 13871

# %%
tp = float(len(newdata[(newdata.sentiment == 'Positive') & (newdata.prediction == 'Positive')]))
tn = float(len(newdata[(newdata.sentiment == 'Negative') & (newdata.prediction == 'Negative')]))
trn = float(len(newdata[(newdata.sentiment == 'Neutral') & (newdata.prediction == 'Neutral')]))
top = float(len(newdata[(newdata.sentiment == 'Neutral')]))
fp = float(len(newdata[(newdata.sentiment == 'Positive')]))
fn = float(len(newdata[(newdata.sentiment == 'Negative')]))
print ("True Positives: {}".format(tp))
print ("True Negatives:{}".format(tn))
print ("True Neutral:{}" .format(trn))
print ("Total Neutral:{}".format(top))
print ("Total Positives:{}".format(fp))
print ("Total Negatives:{}".format(fn))
total = (float)(len(newdata))
#r = float(tp)/(tp + fn)
#print ("recall", r)

p =(tp) / (fp)
print("precision - positive: {}".format(p))

p1 = (tn) / (fn)
print("precision - negative: {}".format(p1))

p2 = (trn) / (top)
print("precision - neutral: {}".format(p2))

true = (float)(len(newdata[(newdata.sentiment == newdata.prediction)]))
false = (float)(total - true)
print('Correctly predicted = {}'.format(true))
print('Accuracy ={} '.format(true/total))
# Out:
# True Positives: 584.0
# True Negatives:3019.0
# True Neutral:2288.0
# Total Neutral:3142.0
# Total Positives:2236.0
# Total Negatives:8493.0
# precision - positive: 0.261180679785
# precision - negative: 0.355469209938
# precision - neutral: 0.728198599618
# Correctly predicted = 5891.0
# Accuracy =0.424699012328
